# %% [markdown]
# # The Sparks Foundation

# %% [markdown]
# * Task: Create Decision Tree Classifier and Visualize it Graphically
# * Dataset Link : https://bit.ly/3kXTdox
#
# * Decision Tree is a Supervised ML Algorithm
# *How Decision Tree Works*
#
# ![image1.png](attachment:image1.png)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv("Iris.csv")

# %%
df.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB

# %%
df.drop(columns="Id",inplace=True)

# %% [markdown]
# The Dataset Contains **150 row** and **6 columns** and there is no null data is present in this dataset.
# # EDA

# %%
df.isnull().sum()
# Out:
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %%
df.describe()
# Out:
#        SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count     150.000000    150.000000     150.000000    150.000000
# mean        5.843333      3.054000       3.758667      1.198667
# std         0.828066      0.433594       1.764420      0.763161
# min         4.300000      2.000000       1.000000      0.100000
# 25%         5.100000      2.800000       1.600000      0.300000
# 50%         5.800000      3.000000       4.350000      1.300000
# 75%         6.400000      3.300000       5.100000      1.800000
# max         7.900000      4.400000       6.900000      2.500000

# %%
sns.displot(df["SepalLengthCm"],kde=True)
plt.title("Distribution of SepalLengthCM")
plt.show()

# %%
sns.displot(df["SepalWidthCm"],kde=True)
plt.title("Distribution of SepalWidthCm")
plt.show()

# %%
sns.displot(df["PetalLengthCm"],kde=True)
plt.title("Distribution of PetalLengthCm")
plt.show()

# %%
sns.displot(df["PetalWidthCm"],kde=True)
plt.title("Distribution of PetalWidthCm")
plt.show()

# %%
sns.countplot(x=df['Species'])
plt.title('Distribution of Target values')
plt.show()

# %%
df.head()
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0            5.1           3.5            1.4           0.2  Iris-setosa
# 1            4.9           3.0            1.4           0.2  Iris-setosa
# 2            4.7           3.2            1.3           0.2  Iris-setosa
# 3            4.6           3.1            1.5           0.2  Iris-setosa
# 4            5.0           3.6            1.4           0.2  Iris-setosa

# %%
plt.figure(figsize=(8,6))
sns.scatterplot(x=df['SepalLengthCm'],
               y=df['SepalWidthCm'],hue=df['Species'])

plt.title("SepalLengthCm vs SepalWidthCm")
plt.show()

# %%
df.head()
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0            5.1           3.5            1.4           0.2  Iris-setosa
# 1            4.9           3.0            1.4           0.2  Iris-setosa
# 2            4.7           3.2            1.3           0.2  Iris-setosa
# 3            4.6           3.1            1.5           0.2  Iris-setosa
# 4            5.0           3.6            1.4           0.2  Iris-setosa

# %%
plt.figure(figsize=(8,6))
sns.scatterplot(x=df['PetalLengthCm'],
               y=df['PetalWidthCm'],hue=df['Species'])

plt.title("PetalLengthCm vs PetalWidthCm")
plt.show()

# %% [markdown]
# # Data Preprocessing

# %%
from sklearn.preprocessing import LabelEncoder,OneHotEncoder
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn.tree import plot_tree

# %%
# Independent Variables
x = df.drop(columns="Species")
# Dependent Variables
y = df["Species"]

# %%
label = LabelEncoder()

# %%
label.fit(y)
# Out:
# LabelEncoder()

# %%
y = label.transform(y)

# %%
# spliting data into training and testing
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.3,random_state=1)

# %%
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (105, 4)
# (45, 4)
# (105,)
# (45,)

# %% [markdown]
# # Model Building

# %%
tree = DecisionTreeClassifier()

# %%
# Training the dataset using training data
tree.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
# Testing the datase using test data
y_pred = tree.predict(x_test)

# %%
y_pred
# Out:
# array([0, 1, 1, 0, 2, 1, 2, 0, 0, 2, 1, 0, 2, 1, 1, 0, 1, 1, 0, 0, 1, 1,
#        2, 0, 2, 1, 0, 0, 1, 2, 1, 2, 1, 2, 2, 0, 1, 0, 1, 2, 2, 0, 1, 2,
#        1])

# %%
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        14
#            1       0.94      0.94      0.94        18
#            2       0.92      0.92      0.92        13
#
#     accuracy                           0.96        45
#    macro avg       0.96      0.96      0.96        45
# weighted avg       0.96      0.96      0.96        45

# %%
print("Accuracy Score on Training data: ",accuracy_score(y_train,tree.predict(x_train)))
print("Accuracy Score on Testing data: ",accuracy_score(y_test,tree.predict(x_test)))
# Out:
# Accuracy Score on Training data:  1.0
# Accuracy Score on Testing data:  0.9555555555555556

# %%
sns.heatmap(confusion_matrix(y_test,y_pred),annot=True)
plt.xlabel("Actual Label")
plt.ylabel("Predicted Label")
plt.title("Accuracy Score: {}".format(round(tree.score(x_test,y_test),2)))
plt.show()

# %%
# Visualization of Decision Tree
plt.figure(figsize=(12,9))
plot_tree(tree,
          feature_names =x.columns,
         class_names=["Setosa","Vercicolor","Verginica"],
         filled=True,
         precision=4,
         rounded=True)
plt.show()
